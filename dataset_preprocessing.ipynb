# %%
import glob
import os
import cv2
import numpy as np
from PIL import Image
import torch 
from PIL import Image
from pathlib import Path
import torchvision.transforms as T
import torchvision.transforms.functional as TF
import numpy as np
from torchvision import transforms
import os
import cv2
import matplotlib.pyplot as plt
import shutil
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import glob
#       2 import os
# ----> 3 import cv2
#       4 import numpy as np
#       5 from PIL import Image
#
# ModuleNotFoundError: No module named 'cv2'

# %%
source = "/home/wej36how/datasets/NWRDF/train"
dest = "/home/wej36how/datasets/NWRDFProcessed/train"
patch_size = 224
rust_threshold = 150
max_number_of_images_per_group = 12

# %% [markdown]
# This snippet will make patches of the images in the destination/patches directory.

# %%
masks_paths = glob.glob(f'{os.path.join(source, "masks", "*")}')
images_paths = glob.glob(f'{os.path.join(source, "images", "*")}')
images_paths.sort()
masks_paths.sort()

patches_path = os.path.join(dest, "patches")
images_dir = os.path.join(patches_path, "images")
masks_dir = os.path.join(patches_path, "masks")
os.makedirs(patches_path)
os.makedirs(images_dir)
os.makedirs(masks_dir)

def create_patches(fname):
    x = 0
    y = 0
    patches = []
    img = cv2.imread(fname)
    print("image shape:",img.shape)
    p_num = 0
    while (y + patch_size < img.shape[0]):
        
        if (x + patch_size > img.shape[1]):
            x = 0
            y += patch_size
        if y + patch_size <= img.shape[0] and x + patch_size <= img.shape[1]:
            patches.append([x, y])
        x += patch_size
    print("total patches: ", len(patches))
    return patches

total_count = 0
for u in images_paths:
    print(u)
    patches = create_patches(u)
    bgr = cv2.imread(u)
    image_name = u.split('/')[-1].split('.')[0]
    total_count += len(patches)

    for count, P in enumerate(patches):
        cv2.imwrite(os.path.join(images_dir,f"{image_name}_{count}.png"), bgr[P[1]:P[1]+patch_size,P[0]:P[0]+patch_size])
            
print("total image count:", total_count)

total_count = 0
for u in masks_paths:
    print(u)
    patches = create_patches(u)
    bgr = cv2.imread(u)
    image_name = u.split('/')[-1].split('.')[0]

    total_count += len(patches)

    for count, P in enumerate(patches):
        cv2.imwrite(os.path.join(masks_dir,f"{image_name}_{count}.png"), bgr[P[1]:P[1]+patch_size,P[0]:P[0]+patch_size])
            
print("total masks count:", total_count)
# Out:
# /home/wej36how/datasets/NWRDF/train/images/1.JPG
# image shape: (4000, 6016, 3)
# total patches:  442
# /home/wej36how/datasets/NWRDF/train/images/10.JPG
# image shape: (4000, 6016, 3)
# total patches:  442
# /home/wej36how/datasets/NWRDF/train/images/10_0.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_1.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_10.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_100.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_101.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_102.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_103.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_104.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_105.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_106.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_107.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_108.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_109.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_11.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_110.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_111.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_112.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_113.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_114.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_115.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_116.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_117.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_118.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_119.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_12.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_120.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_121.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_122.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_123.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_124.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_125.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_126.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_127.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_128.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_129.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_13.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_130.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_131.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_132.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_133.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_134.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_135.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_136.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_137.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_138.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_139.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_14.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_140.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_141.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_142.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_143.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_144.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_145.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_146.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_147.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_148.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_149.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_15.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_150.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_151.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_152.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_153.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_154.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_155.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_156.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_157.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_158.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_159.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_16.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_160.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_161.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_162.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_163.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_164.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_165.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_166.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_167.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_168.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_169.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_17.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_170.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_171.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_172.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_173.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_174.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_175.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_176.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_177.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_178.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_179.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_18.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_180.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_181.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_182.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_183.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_184.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_185.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_186.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_187.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_188.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_189.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_19.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_190.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_191.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_192.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_193.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_194.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_195.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_196.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_197.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_198.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_199.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_2.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_20.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_200.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_201.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_202.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_203.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_204.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_205.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_206.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_207.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_208.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_209.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_21.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_210.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_211.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_212.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_213.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_214.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_215.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_216.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_217.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_218.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_219.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_22.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_220.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_221.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_222.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_223.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_224.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_225.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_226.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_227.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_228.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_229.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_23.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_230.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_231.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_232.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_233.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_234.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_235.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_236.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_237.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_238.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_239.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_24.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_240.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_241.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_242.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_243.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_244.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_245.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_246.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_247.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_248.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_249.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_25.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_250.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_251.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_252.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_253.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_254.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_255.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_256.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_257.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_258.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_259.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_26.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_260.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_261.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_262.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_263.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_264.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_265.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_266.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_267.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_268.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_269.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_27.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_270.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_271.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_272.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_273.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_274.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_275.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_276.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_277.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_278.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_279.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_28.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_280.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_281.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_282.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_283.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_284.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_285.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_286.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_287.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_288.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_289.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_29.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_290.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_291.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_292.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_293.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_294.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_295.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_296.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_297.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_298.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_299.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_3.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_30.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_300.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_301.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_302.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_303.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_304.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_305.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_306.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_307.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_308.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_309.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_31.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_310.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_311.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_312.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_313.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_314.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_315.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_316.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_317.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_318.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_319.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_32.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_320.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_321.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_322.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_323.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_324.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_325.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_326.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_327.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_328.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_329.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_33.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_330.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_331.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_332.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_333.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_334.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_335.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_336.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_337.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_338.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_339.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_34.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_340.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_341.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_342.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_343.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_344.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_345.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_346.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_347.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_348.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_349.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_35.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_350.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_351.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_352.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_353.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_354.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_355.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_356.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_357.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_358.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_359.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_36.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_360.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_361.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_362.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_363.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_364.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_365.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_366.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_367.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_368.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_369.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_37.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_370.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_371.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_372.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_373.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_374.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_375.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_376.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_377.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_378.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_379.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_38.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_380.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_381.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_382.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_383.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_384.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_385.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_386.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_387.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_388.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_389.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_39.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_390.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_391.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_392.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_393.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_394.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_395.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_396.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_397.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_398.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_399.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_4.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_40.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_400.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_401.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_402.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_403.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_404.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_405.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_406.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_407.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_408.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_409.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_41.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_410.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_411.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_412.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_413.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_414.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_415.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_416.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_417.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_418.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_419.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_42.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_420.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_421.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_422.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_423.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_424.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_425.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_426.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_427.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_428.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_429.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_43.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_430.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_431.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_432.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_433.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_434.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_435.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_436.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_437.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_438.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_439.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_44.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_440.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_441.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_45.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_46.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_47.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_48.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_49.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_5.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_50.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_51.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_52.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_53.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_54.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_55.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_56.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_57.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_58.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_59.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_6.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_60.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_61.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_62.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_63.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_64.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_65.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_66.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_67.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_68.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_69.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_7.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_70.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_71.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_72.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_73.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_74.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_75.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_76.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_77.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_78.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_79.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_8.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_80.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_81.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_82.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_83.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_84.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_85.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_86.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_87.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_88.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_89.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_9.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_90.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_91.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_92.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_93.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_94.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_95.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_96.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_97.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_98.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/10_99.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11.JPG
# image shape: (4000, 6016, 3)
# total patches:  442
# /home/wej36how/datasets/NWRDF/train/images/11_0.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_1.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_10.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_100.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_101.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_102.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_103.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_104.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_105.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_106.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_107.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_108.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_109.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_11.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_110.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_111.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_112.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_113.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_114.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_115.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_116.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_117.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_118.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_119.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_12.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_120.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_121.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_122.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_123.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_124.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_125.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_126.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_127.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_128.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_129.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_13.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_130.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_131.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_132.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_133.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/11_134.png
# image shape: (224, 224, 3)
# total patches:  0
# ...
# /home/wej36how/datasets/NWRDF/train/images/14_156.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_157.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_158.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_159.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_16.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_160.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_161.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_162.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_163.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_164.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_165.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_166.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_167.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_168.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_169.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_17.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_170.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_171.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_172.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_173.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_174.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_175.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_176.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_177.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_178.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_179.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_18.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_180.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_181.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_182.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_183.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_184.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_185.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_186.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_187.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_188.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_189.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_19.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_190.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_191.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_192.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_193.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_194.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_195.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_196.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_197.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_198.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_199.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_2.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_20.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_200.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_201.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_202.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_203.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_204.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_205.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_206.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_207.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_208.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_209.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_21.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_210.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_211.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_212.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_213.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_214.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_215.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_216.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_217.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_218.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_219.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_22.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_220.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_221.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_222.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_223.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_224.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_225.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_226.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_227.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_228.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_229.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_23.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_230.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_231.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_232.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_233.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_234.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_235.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_236.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_237.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_238.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_239.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_24.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_240.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_241.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_242.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_243.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_244.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_245.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_246.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_247.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_248.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_249.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_25.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_250.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_251.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_252.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_253.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_254.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_255.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_256.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_257.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_258.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_259.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_26.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_260.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_261.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_262.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_263.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_264.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_265.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_266.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_267.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_268.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_269.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_27.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_270.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_271.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_272.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_273.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_274.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_275.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_276.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_277.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_278.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_279.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_28.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_280.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_281.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_282.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_283.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_284.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_285.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_286.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_287.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_288.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_289.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_29.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_290.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_291.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_292.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_293.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_294.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_295.png
# image shape: (224, 224, 3)
# total patches:  0
# /home/wej36how/datasets/NWRDF/train/images/14_296.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3360090/378251804.py in <cell line: 32>()
#      32 for u in images_paths:
#      33     print(u)
# ---> 34     patches = create_patches(u)
#      35     bgr = cv2.imread(u)
#      36     image_name = u.split('/')[-1].split('.')[0]
#
# /tmp/ipykernel_3360090/378251804.py in create_patches(fname)
#      15     y = 0
#      16     patches = []
# ---> 17     img = cv2.imread(fname)
#      18     print("image shape:",img.shape)
#      19     p_num = 0
#
# KeyboardInterrupt:

# %% [markdown]
# This will saperate the rust and non rust patches and put them in and put them in directory destination/RustNonRustSplit

# %%
destination = os.path.join(dest, "RustNonRustSplit")
root = patches_path

os.makedirs(destination)
os.makedirs(os.path.join(destination,"non_rust","images"))
os.makedirs(os.path.join(destination,"non_rust","masks"))
os.makedirs(os.path.join(destination,"rust","images"))
os.makedirs(os.path.join(destination,"rust","masks"))

masks_path = os.path.join(root, "masks", "*.png")
masks_paths = glob.glob(masks_path)
minimum=1000
min_patch=0
rust_count=0
non_rust_count=0

for mask_path in masks_paths:
    patch_name = mask_path.split("/")[-1].split(".")[0]
    
    patch_mask = cv2.imread(mask_path, 0)
    patch_img = cv2.imread(os.path.join(root, "images",patch_name+".png"))

    condition = (patch_mask > 150)
    count = np.sum(condition)
        
    if count<=rust_threshold:
            cv2.imwrite(os.path.join(destination,"non_rust","images",f"{patch_name}.png"), patch_img)
            cv2.imwrite(os.path.join(destination,"non_rust","masks",f"{patch_name}.png"), patch_mask)
            non_rust_count+=1
    else:
            if (count<=minimum):
                   minimum=count
                   min_patch = patch_name
            cv2.imwrite(os.path.join(destination,"rust","images",f"{patch_name}.png"), patch_img)
            cv2.imwrite(os.path.join(destination,"rust","masks",f"{patch_name}.png"), patch_mask)
            rust_count+=1

print("minimum rust patch:",min_patch)
print("minimum rust patch white pixels:",minimum)
print("rust count=", rust_count)
print("non rust count=", non_rust_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2812573/2396489626.py in <cell line: 1>()
# ----> 1 destination = os.path.join(dest, "RustNonRustSplit")
#       2 root = patches_path
#       3
#       4 os.makedirs(destination)
#       5 os.makedirs(os.path.join(destination,"non_rust","images"))
#
# NameError: name 'os' is not defined

# %% [markdown]
# Run the next two code snippets for training only. The following code will augment the images in the destination/RustNonRustSplit/images and destination/RustNonRustSplit/masks folder.

# %%
#flip images horizontally
def flip_images_hor(input_image):
    # Iterate over the images in the input directory
    transform_hflip = T.RandomHorizontalFlip(p=1.0)  # Set probability to 1.0 to always flip
    return transform_hflip(input_image)

#flip images vertically
def flip_images_ver(input_image):
    # Iterate over the images in the input directory
    transform_vflip = T.RandomVerticalFlip(p=1.0)  # Set probability to 1.0 to always flip
    return transform_vflip(input_image) 
  
def shear_vertical(input_image, shear_factor=45):
    # Apply vertical shear
    sheared_image = TF.affine(input_image, angle=0, translate=(0, 0), scale=1, shear=(0, shear_factor))
    return sheared_image

def shear_horizontal(input_image, shear_factor=45):  # Increased shear for testing
    sheared_image = TF.affine(input_image, angle=0, translate=(0, 0), scale=1, shear=(shear_factor, 0))
    return sheared_image

def rotate_images(input_image, angle=45):
    # Convert PIL Image to NumPy array
    input_array = np.array(input_image)
    # Rotate the image
    height, width = input_array.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1)
    rotated_array = cv2.warpAffine(input_array, rotation_matrix, (width, height))
    # Convert NumPy array back to PIL Image
    rotated_image = Image.fromarray(rotated_array)
    return rotated_image

def dark(input_image,gamma):
    dark_image= TF.adjust_gamma(input_image, gamma)
    return dark_image

def augment_image(img_path):

  # Apply the transformations
  
    #orig_image
    orig_img = Image.open(Path(img_path))
    
    #flip images
    img_hflipped = flip_images_hor(orig_img)
    img_vflipped = flip_images_ver(orig_img)
    
    
    #shear images
    hor_shear = shear_horizontal(orig_img)
    ver_shear = shear_vertical(orig_img)
    
    #dark
    img_dark = dark(img_hflipped, 2)
    img_rot = rotate_images(orig_img, angle=45)
    
    return [img_dark,img_hflipped,img_vflipped,hor_shear,ver_shear, img_rot]

def creating_file_with_augmented_images(file_path_master_dataset, file_path_augmented_images):
    master_dataset_folder = file_path_master_dataset
    files_in_master_dataset = os.listdir(file_path_master_dataset)
    augmented_images_folder = file_path_augmented_images
    
    for image_name in files_in_master_dataset:
        image_path = os.path.join(master_dataset_folder, image_name)
        required_images = augment_image(image_path)  # Assuming augment_image is defined elsewhere
        i = 0
        for augmented_image in required_images:
            # Convert RGBA to RGB if necessary
            if augmented_image.mode == 'RGBA':
                augmented_image = augmented_image.convert('RGB')
                
            # Save as png
            augmented_image_path = os.path.join(augmented_images_folder, f"aug{i}_{image_name}")
            augmented_image.save(augmented_image_path, format='png')
            i += 1

master_dataset = os.path.join(destination,"rust","images")
augmented_dataset = os.path.join(destination,"rust","images")
creating_file_with_augmented_images(master_dataset,augmented_dataset)

master_dataset = os.path.join(destination,"rust","masks")
augmented_dataset = os.path.join(destination,"rust","masks")
creating_file_with_augmented_images(master_dataset,augmented_dataset)

# %% [markdown]
# Run next snippet only for training dataset. To remove patches that have their rust removed becuase of their augmentations

# %%
root = os.path.join(destination,"rust")

non_rust_images_dir = os.path.join(destination,"non_rust","images")
non_rust_masks_dir = os.path.join(destination,"non_rust","masks")

masks_path = os.path.join(root, "masks", "*.png")
masks_paths = glob.glob(masks_path)
minimum=1000
min_patch=0
rust_count=0
non_rust_count=0

for mask_path in masks_paths:
    patch_name = mask_path.split("/")[-1].split(".")[0]
    
    patch_mask = cv2.imread(mask_path, 0)
    patch_img = cv2.imread(os.path.join(root, "images",patch_name+".png"))

    condition = (patch_mask > 150)
    count = np.sum(condition)
        
    if count<=rust_threshold:
            os.remove(mask_path)
            os.remove(os.path.join(root, "images",patch_name+".png"))

            cv2.imwrite(os.path.join(non_rust_images_dir,f"{patch_name}.png"), patch_img)
            cv2.imwrite(os.path.join(non_rust_masks_dir,f"{patch_name}.png"), patch_mask)
            non_rust_count+=1
    else:
            if (count<=minimum):
                   minimum=count
                   min_patch = patch_name
        #     cv2.imwrite(os.path.join(destination,"rust","images",f"{patch_name}.png"), patch_img)
        #     cv2.imwrite(os.path.join(destination,"rust","masks",f"{patch_name}.png"), patch_mask)
            rust_count+=1

print("minimum rust patch:",min_patch)
print("minimum rust patch white pixels:",minimum)
print("rust count=", rust_count)
print("non rust count=", non_rust_count)
# Out:
# minimum rust patch: 0
# minimum rust patch white pixels: 1000
# rust count= 0
# non rust count= 0

# %% [markdown]
# Create a dataset for classification model

# %%
rust_images_dir = os.path.join(destination,"rust","images")
non_rust_images_dir = os.path.join(destination,"non_rust","images")

rustClassificationDir = os.path.join(dest, "calssification", "rust")
nonRustClassificationDir = os.path.join(dest, "calssification", "non_rust")
os.makedirs(rustClassificationDir, exist_ok=True)
os.makedirs(nonRustClassificationDir, exist_ok=True)

shutil.copytree(rust_images_dir,rustClassificationDir, dirs_exist_ok=True)
shutil.copytree(non_rust_images_dir,nonRustClassificationDir, dirs_exist_ok=True)
# Out:
# 'C:\\Users\\hasee\\Desktop\\Germany_2024\\Dataset\\NWRDFprocessed\\train\\calssification\\non_rust'

# %% [markdown]
# Run the next code snippet for training dataset only. It deletes non-rust patches to match rust patches in the classification folder only.

# %%
import os
import glob

def delete_extra_images(directory, target_count):
    # Get a list of all image files in the directory
    image_files = glob.glob(os.path.join(directory, '*.JPG')) + glob.glob(os.path.join(directory, '*.jpeg')) + glob.glob(os.path.join(directory, '*.png'))
    
    # Check if the number of images exceeds the target count
    if len(image_files) > target_count:
        # Calculate the number of images to delete
        num_to_delete = len(image_files) - target_count
        # Sort the images by modification time (oldest first)
        image_files.sort(key=os.path.getmtime)
        # Delete the extra images
        for i in range(num_to_delete):
            os.remove(image_files[i])
        print(f"{num_to_delete} images deleted.")
    elif len(image_files) < target_count:
        print("Warning: Number of images in directory is less than the target count.")

if len(os.listdir(rustClassificationDir))< len(os.listdir(nonRustClassificationDir)):
    delete_extra_images(nonRustClassificationDir, len(os.listdir(rustClassificationDir)))
else:
    delete_extra_images(rustClassificationDir, len(os.listdir(nonRustClassificationDir)))

# %% [markdown]
# The following code creates a coslaiency style structure for co-saliency models training

# %%
rust_dir = os.path.join(destination,"rust")
rustCosaliencynDir = os.path.join(dest, "cosaliency")
shutil.copytree(rust_dir,rustCosaliencynDir, dirs_exist_ok=True)

# Function to split images into folders based on image number
def split_images_into_folders(source_dir, destination_dir):
    # Create destination directory if it doesn't exist
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)
    # Iterate through files in the source directory
    for filename in os.listdir(source_dir):
        if filename.endswith('.png'):
            image_no = filename.split('_')[0]  # Extract image number from filename
            if not image_no.isdigit():
                image_no = filename.split('_')[1]
            destination_subdir = os.path.join(destination_dir, image_no)
            # Create subdirectory if it doesn't exist
            if not os.path.exists(destination_subdir):
                os.makedirs(destination_subdir)
            # Move the image file to the respective subdirectory
            shutil.move(os.path.join(source_dir, filename), destination_subdir)

def organize_images(main_directory):
    # Ensure the main directory exists
    if not os.path.exists(main_directory):
        print(f"The specified main directory '{main_directory}' does not exist.")
        return

    # Get a list of subdirectories in the main directory
    subdirectories = [d for d in os.listdir(main_directory) if os.path.isdir(os.path.join(main_directory, d))]

    # Process each subdirectory
    for subdir in subdirectories:
        subdir_path = os.path.join(main_directory, subdir)

        # Get a list of images in the subdirectory
        images = [f for f in os.listdir(subdir_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.gif'))]
        # Determine the number of images per subdirectory
        images_per_subdir = 12
        num_subdirectories = len(images) // images_per_subdir
        n=0
        # Create additional subdirectories if needed
        for i in range(num_subdirectories - 1):
            new_subdir_name = f"{subdir}_part{i + 1}"
            new_subdir_path = os.path.join(main_directory, new_subdir_name)

            # Create the new subdirectory
            os.makedirs(new_subdir_path)

            # Move images to the new subdirectory
            for j in range(images_per_subdir):
                old_image_path = os.path.join(subdir_path, images[n])
                new_image_path = os.path.join(new_subdir_path, images[n])
                shutil.move(old_image_path, new_image_path)
                n+=1

source_directory = os.path.join(dest, "cosaliency", "images")
destination_directory = os.path.join(dest, "cosaliency", "images")
split_images_into_folders(source_directory, destination_directory)
organize_images(destination_directory)

source_directory = os.path.join(dest, "cosaliency", "masks")
destination_directory = os.path.join(dest, "cosaliency", "masks")
split_images_into_folders(source_directory, destination_directory)
organize_images(destination_directory)
